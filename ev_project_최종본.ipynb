# %%
from selenium import webdriver
import time
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from urllib.parse import urljoin
import re

# %%
driver =  webdriver.Chrome(executable_path = 'D:\workspace\chromedriver.exe' )

driver.get('https://ev.or.kr/evmonitor')
#time.sleep(5)

# %%
sid = []

# %%
for k in range(2,19):
    driver.find_element_by_css_selector('#F_SI_DO1')
    driver.implicitly_wait(5)
    driver.find_element_by_css_selector('#F_SI_DO1 > option:nth-child(%s)'%k).click()
    #time.sleep(3)
    driver.find_element_by_css_selector('#statList')
    driver.implicitly_wait(30)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    a = soup.find_all('div',class_='fw_path')
    for link in a:
        temp = str(link['sid'])
        sid.append(temp)

# %%
len(sid)
# Out:
# 2492

# %%
name =[]  #이름
add = []  #주소
time =[]  #사용가능시간
typ = []  # 구분
agency = [] # 운영기관
phone = [] # 연락처
fee = [] # 충전요금
amount = [] # 급속충전량
etc = [] # 참고사항
nouse = [] # 운전상태
using = []
ben = []
charge = []

# %%
for i in sid:
    url_base = 'https://www.ev.or.kr/portal/monitor/evminfo?sid='
    url = url_base+str(i)
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    
    n_tmp = soup.find_all('h2')
    name.append(n_tmp[0].get_text())
    
    t_tmp = soup.find_all('em')
    time.append(t_tmp[0].get_text())
    
    ty_tmp = soup.find_all('dd')
    typ.append(ty_tmp[0].get_text())

    info_tmp = soup.find_all(class_='table_02')
    dinfo = info_tmp[0].find_all('td')
    add.append(dinfo[0].get_text())
    agency.append(dinfo[1].get_text())
    phone.append(dinfo[2].get_text())
    tmp_fee = dinfo[3].get_text()
    tmp_fee = re.sub('&nbsp; | &nbsp; |\n|\t|\r|', '', tmp_fee)
    fee.append(tmp_fee)
    tmp_amount = dinfo[4].get_text()
    tmp_amount = re.sub('&nbsp; | &nbsp; |\n|\t|\r|', '', tmp_amount)
    amount.append(tmp_amount)
    tmp_etc = dinfo[5].get_text()
    tmp_etc = re.sub('&nbsp; | &nbsp; |\n|\t|\r|', '', tmp_etc)
    etc.append(tmp_etc)
    no=0
    use=0
    den=0
    for tmp_using in soup.find_all(class_='td3'):
        a = tmp_using.find_all('span')
        tmp = a[0].get_text()
        if tmp =='사용가능':
            no +=1
        elif tmp == '사용중':
            use +=1
        else:
            den +=1
    nouse.append(no)
    using.append(use)
    ben.append(den)
    
    td2 = soup.find_all(class_='td2')
    for te in td2[0:]:
        test=[]
        for a in te.find_all('span'):
            if a.get_text()=='사용가능':
                break
            elif a.get_text()=='사용중':
                break
            elif a.get_text()=='사용불가':
                break
            elif a.get_text()==' ':
                break
            elif len(a.get_text())<6:
                tmp=[]
                tmp.append(a.get_text())
                #print(tmp)
                test+=tmp
        test= str("+".join(test))
        charge.append(test)
        if test!=None:
            break

    t04 = soup.find_all(class_='ev_type t04')
    for te in t04[1:]:
        print(len(c))
        print(c.get_text())
        test=[]
        for b in te.find_all('span'):
            if len(b.get_text())<6:
                tmp=[]
                tmp.append(b.get_text())
                test+=tmp
        test= str("+".join(test))
        #print(test)
        charge.append(test)
        if test!=None:
            break

# %%
charge
# Out:
# ['DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  '',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  '',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC차데모+AC3상+DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  'DC콤보',
#  ...]

# %%
name
# Out:
# ['DMC 산학협력연구센터',
#  'Park M (주차복합빌딩)',
#  'SETEC',
#  'sh서울주택도시공사',
#  '가로공원로 지하공영주차장',
#  '가양레포츠센터',
#  '가오리 공영주차장',
#  '강남구청 삼성로 별관 부설 주차장',
#  '강남치매지원센터 공영노외주차장',
#  '강동구청',
#  '강변 공영주차장',
#  '강서구민올림픽체육센터',
#  '개봉1동 주민센터 옆 공영주차장',
#  '개포동공원 공영주차장',
#  '거여동공영주차장',
#  '곰달래공영주차장',
#  '곰달래문화복지센터 공영주차장',
#  '공덕1-1공영주차장',
#  '구로리공원 앞(공중전화부스)',
#  '구룡공원 공영주차장',
#  '구민회관',
#  '구파발광역환승센터 주차장',
#  '구파발역 환승주차장',
#  '국립극장',
#  '국방부 서문 주차장',
#  '국회도서관',
#  '국회의원회관',
#  '그랜드앰배서더 서울',
#  '그랜드힐튼호텔',
#  '난곡동 제1공영주차장',
#  '난향동 주민센터',
#  '남가좌2동 공영주차장',
#  '냉천길 공영주차장',
#  '노보텔',
#  '노원에코센터',
#  '노을공원',
#  '논현로22길 공영주차장',
#  '논현초교 공영노외주차장',
#  '다락골공영주차장',
#  '당산에스에이치빌 아파트 앞',
#  '대청역 공영주차장',
#  '도봉구청',
#  '도봉기적의도서관',
#  '도봉산환승주차장',
#  '독산1동 공영주차장',
#  '동대문구청',
#  '동작주차공원 공영주차장',
#  '롯데 VIC마켓 금천점',
#  '롯데 VIC마켓 도봉점',
#  '롯데 빅마켓',
#  '롯데마트 구로점',
#  '롯데마트 김포공항점',
#  '롯데마트 삼양점',
#  '롯데마트 서울양평점',
#  '롯데마트 송파점',
#  '롯데마트 은평점',
#  '롯데마트 잠실점',
#  '롯데마트 중계점',
#  '롯데백화점 본점',
#  '마곡레포츠센터 ',
#  '마장동사무소 앞(공중전화부스)',
#  '마장축산물시장 서문 공영주차장',
#  '마천동2공영주차장',
#  '마포공영주차장',
#  '마포중앙도서관',
#  '망원동 공영주차장1',
#  '메이필드호텔',
#  '목2동 주민센터',
#  '목4동주민센터',
#  '문화회관동측 주차장',
#  '미도아파트 앞 공영주차장',
#  '미아동 공영주차장',
#  '번동햇살 공영주차장',
#  '볏골공원 지하공영주차장',
#  '보라매 제1공영주차장',
#  '부암동 주민센터',
#  '북한산국립공원 정릉탐방지원센터',
#  '북한산국립공원주차장',
#  '빅마켓 도봉점',
#  '사당역 공영주차장',
#  '상계2동 공영주차장',
#  '상암1 공영주차장',
#  '서울대입구 교차로',
#  '서울만남휴게소(부산방향)',
#  '서울시인재개발원',
#  '서울약령시 공영주차장',
#  '서울역사박물관',
#  '서울의료원',
#  '서울추모공원',
#  '서초구청',
#  '성북벤처빌딩 공영주차장',
#  '성수 2가1동 공영주차장',
#  '성수2가 공영주차장',
#  '성애병원',
#  '세종로 공영주차장',
#  '송정동 공영주차장',
#  '수서역 공영주차장',
#  '수유마을시장 공영주차장',
#  '스탠포드호텔코리아',
#  '시민의숲동측 공영주차장',
#  '시설관리공단 마포유수지주차장',
#  '시흥제4동공영주차장',
#  '신길 제5동 주민센터',
#  '신길4동1마을공원 공영주차장',
#  '신림동 제1공영주차장',
#  '신월5동 주민센터',
#  '신정1동 주민센터',
#  '신정3동 넓은들 민원센터',
#  '신창동 공영주차장',
#  '실증용 Mock-up 주택 홍보관',
#  '쌍문2동 제3공영주차장',
#  '쌍문3동 제2공영주차장',
#  '아시아공원 공영주차장',
#  '암사1동 공영주차장',
#  '압구정 428 공영주차장1',
#  '압구정로29길 공영노상주차장',
#  '양화진 공영주차장',
#  '양화진공영주차장',
#  '어린이대공원 후문주차장',
#  '영등포 제3공영',
#  '영등포구 대신시장(공중전화부스)',
#  '영등포구청 환승공영주차장',
#  '영등포본동제1(공영주차장)',
#  '예금보험공사',
#  '올림픽공원',
#  '용답동 공영주차장',
#  '용마폭포공원 공영주차장',
#  '우리은행본점',
#  '원신 공영주차장',
#  '은평구민체육센터',
#  '응봉동 공영주차장',
#  '이마트 명일점',
#  '이마트 양재점',
#  '이마트 은평점',
#  '이마트 은평점',
#  '이마트 이문점',
#  '이태원2동공영주차장',
#  '일원2동 주민센터',
#  '일원본동 주민센터',
#  '제일모직아울렛 건너편(공중전화부스)',
#  '조원동 제1공영주차장',
#  '종묘 공영주차장',
#  '중앙대학교병원 다정관 주차장',
#  '창2동 제4공영주차장',
#  '창3동 제1공영주차장',
#  '창천공영주차장',
#  '천마공영주차장',
#  '천왕역 환승주차장',
#  '천호3동 제1공영주차장',
#  '천호유수지 공영주차장',
#  '청량리롯데백화점',
#  '충현동 제1공영주차장',
#  '탄천물재생센터',
#  '탄천제2호 공영주차장',
#  '태화빌딩',
#  '파크하얏트서울호텔',
#  '하늘공원주차장',
#  '하왕십리 공영주차장',
#  '학여울역 공영주차장',
#  '한강진역 공영주차장',
#  '한국예술종합학교(종로)',
#  '한국원자력의학원 본사',
#  '한국장애인개발원 본사',
#  '한남동 공영주차장',
#  '해누리타운',
#  '해맞이공영주차장',
#  '현대남부서비스센터',
#  '현대자동차 수색대리점',
#  '현대차 남부서비스센터',
#  '홈플러스 가양점',
#  '홈플러스 강서점',
#  '홈플러스 금천점',
#  '홈플러스 면목점',
#  '홈플러스 목동점',
#  '홈플러스 상봉점',
#  '홈플러스 시흥점',
#  '홈플러스 신내점',
#  '홈플러스 신도림점',
#  '홈플러스 영등포점',
#  '홈플러스 월곡점',
#  '홈플러스 월드컵점',
#  '홈플러스 중계점',
#  '홍제견인차량보관소 주차장',
#  '화곡6-1 공영주차장',
#  'kbs 부산방송총국',
#  '국립부산과학관',
#  '기장군청',
#  '기장시장 공영주차장',
#  '기장현대드림볼파크',
#  '김해공항',
#  '남산역 공영주차장',
#  '덕천 공영주차장',
#  '동래역 공영주차장 ',
#  '동원 공영주차장',
#  '롯데마트 광복점',
#  '롯데마트 동래점',
#  '롯데마트 부산점',
#  '롯데마트 사상점',
#  '롯데마트 사하점',
#  '롯데마트 화명점',
#  '망미동 공영주차장',
#  '명장동 공영주차장 ',
#  '부산 어린이 대공원',
#  '부산도시공사',
#  '부산시 교육청',
#  '부산시민공원 지하 주차장',
#  '부산아시아드보조경기장VIP주차장',
#  '부산조선해양기자재공업협동조합',
#  '부산지방경찰청 앞 민원인 주차장',
#  '부산진구청 지하1층 주차장',
#  '부산테크노파크 종합물류경영기술지원센터',
#  '부산환경공단 명지사업소',
#  '부전역 공영주차장',
#  '사하경찰서',
#  '삼락재첩거리',
#  '수변공원',
#  '암남동주민센터',
#  '엄궁초등학교지하 공영주차장',
#  '영도구청',
#  '온천장역 공영주차장',
#  '용두산 공영주차장',
#  '이마트 금정점',
#  '이마트 문현점',
#  '이마트 연제점',
#  '이마트 해운대점',
#  '장안읍사무소',
#  '장안천야구장',
#  '장안휴게소(울산방향)',
#  '장전역 공영주차장',
#  '정관노인복지관',
#  '정관보건지소',
#  '정관읍사무소',
#  '종합사회복지관',
#  '중동역 공영주차장',
#  '철마면사무소',
#  '철마체육시설',
#  '하단역 공영주차장',
#  '학장천 공영주차장',
#  '한국공항공사 부산지역본부 김해공항 옥외주차장',
#  '한국공항공사 부산지역본부 김해공항 주차빌딩',
#  '한국마사회 부산경남지역본부',
#  '한국수력원자력 고리원자력본부',
#  '홈플러스 아시아드점',
#  '홈플러스 영도점',
#  'SW융합기술지원센터',
#  '㈜정방',
#  '강당골 공영주차장',
#  '계명문화대학교',
#  '구지면사무소',
#  '국가물산업클러스터 주차장',
#  '낙동강 레포츠밸리',
#  '낙동강승전기념관',
#  '노원동행정복지센터',
#  '논공공단주유소',
#  '논공휴게소(광주방향)',
#  '논공휴게소(대구방향)',
#  '달서별빛캠프 캠핑장',
#  '달성군 보건소',
#  '달성문화원',
#  '대구 문화예술회관',
#  '대구광역시청 별관',
#  '대구교통연수원',
#  '대구보건환경연구원',
#  '대구시청',
#  '대구지방합동청사',
#  '대구환경공단 달성사업소',
#  '대구환경공단 신천사업소',
#  '대명1동 행정복지센터',
#  '도원동마을공영주차장',
#  '두류공원관리소',
#  '만촌1동주민센터',
#  '만평네거리 북편 공영주차장',
#  '망우당공원 택시쉼터',
#  '무학산공원',
#  '범물공영주차장',
#  '복현2동주민센터',
#  '북구구민 운동장',
#  '북구유통단지(EXCO)',
#  '북대구세무서',
#  '블루핸즈 현풍현대서비스',
#  '비슬산 숲속 캠핑장',
#  '서구 문화회관',
#  '서변2공영주차장',
#  '서재문화체육센터',
#  '서촌공영주차장',
#  '성명맨션 앞(공중전화부스)',
#  '성서국민체육센터',
#  '수태골 공영주차장',
#  '시지근린공원 공영주차장',
#  '신암5동주민센터',
#  '안심2동 공영주차장',
#  '연암공원',
#  '용산역환승주차장',
#  '웃는얼굴 아트센터',
#  '원평치안센터(공중전화부스)',
#  '율암동 공영주차장',
#  '이곡2동주민센터',
#  '중앙119 구조본부',
#  '진천환승공영주차장',
#  '청소년수련관공영주차장',
#  '칠곡3지구 공영주차장',
#  '침산3동행정복지센터',
#  '침산공원',
#  '팔달신시장공영주차장',
#  '해안동 공영주차장',
#  '현풍백년도깨비시장 공영주차장',
#  '현풍휴게소(대구방향)',
#  '현풍휴게소(현풍방향)',
#  '호산공영주차장',
#  '호텔아젤리아',
#  '홀마트 앞 (공중전화부스)',
#  '황금2동주민센터 앞 공영주차장',
#  '㈜현대자동차 블루핸즈 서인천 서비스 주차장 입구',
#  '가좌2동 행정복지센터',
#  '갈산역 공영주차장',
#  '강화경기장',
#  '강화풍물시장 공영주차장',
#  '검단2공영주차장',
#  '계산1택지 공영주차장',
#  '계산3동행정복지센터 주차창',
#  '계양구 공영주차장',
#  '국립생물자원관',
#  '근로복지공단 인천북부지사',
#  '남동복지관',
#  '늘솔길공원 3주차장',
#  '대룡리 공영주차장',
#  '덕산국민여가캠핑장',
#  '도원역 부근 공영주차장',
#  '동화마을 공영주차장',
#  '롯데마트 검단점',
#  '롯데마트 부평역점',
#  '롯데마트 연수점',
#  '롯데마트 영종도점',
#  '롯데마트 영종도점',
#  '롯데마트 인천터미널점',
#  '롯데마트 청라점',
#  '모탱이공원',
#  '문화예술회관공영주차장',
#  '부원 공영주차장',
#  '부평깡시장 공영주차장',
#  '삼산월드체육관',
#  '서곶근린공원 제1주차장',
#  '서운체육공원 주차장',
#  '소래제1주차장',
#  '송도골프',
#  '송도컨벤시아',
#  '송도컨벤시아',
#  '송림체육관',
#  '시립박물관주변 공영주차장',
#  '신기남부종합시장 주차장',
#  '십리포해수욕장 주차장',
#  '아트센터인천',
#  '여성의광장',
#  '연세대학교 국제캠퍼스',
#  '연수구청',
#  '열우물경기장',
#  '영종 하늘문화센터',
#  '영종대교 휴게소 주차장',
#  '영종역남부 공영주차장',
#  '영흥수산물직판장 주차장',
#  '온수리 공영 주차장',
#  '왕산 공영주차장',
#  '월미공원 제2주차장',
#  '월미도 공영주차장',
#  '이마트 동인천점',
#  '이마트 연수점',
#  '인천공항 정부합동청사',
#  '인천공항물류단지 행정지원센터',
#  '인천광역시 교통연수원',
#  '인천교통공사 본사',
#  '인천나비공원 주차장',
#  '인천서구청',
#  '인천서구청 제1주차장',
#  '인천서구청소년수련관',
#  '인천시청',
#  '인천아시아드주경기장 D1주차장',
#  '인천아시안게임 남동경기장 1주차장',
#  '인천정보산업테크노파크',
#  '인천환경공단 가좌사업소',
#  '인천환경공단 운북사업소',
#  '장수서창 공영주차장',
#  '정부인천지방합동청사',
#  '중부지방고용노동청 별관 앞',
#  '차이나타운 주차장',
#  '청라에너지',
#  '청라중앙호수공원 2주차장',
#  '한국폴리텍대학 남인천캠퍼스',
#  '한국환경공단(기후대기관)',
#  '현대시장 공영주차장',
#  '홈플러스 가좌점',
#  '홈플러스 구월점',
#  '홈플러스 인천청라점',
#  '홈플러스 인하점',
#  '518기념문화센터',
#  'IPLEX광주',
#  '계림동 공영주차장',
#  '공무원교육원',
#  '광산구청 구청사',
#  '광산문화예술회관',
#  '광주교육과학연구원',
#  '광주김치타운',
#  '광주도시철도공사',
#  '광주망월주유소',
#  '광주문화예술회관',
#  '광주문화예술회관',
#  '광주시청',
#  '광주테크노파크가전로봇센터',
#  '국립광주박물관',
#  '국민체육센터',
#  '기아자동차 진월점',
#  '남구문화예술회관',
#  '남구청주차장',
#  '농성2동주민센타',
#  '동구다목적체육관 제1주차장',
#  '동구문화센터',
#  '롯데마트 상무점',
#  '롯데마트 수완점',
#  '롯데마트 월드컵점',
#  '롯데마트 첨단점',
#  '무등산생태탐방원',
#  '봉선1동 공영주차장',
#  '블루핸즈 신창진흥점',
#  '블루핸즈 하남현대자동차서비스',
#  '비아5일시장 제2 공영주차장',
#  '사직주민센터',
#  '삼도동주민센터',
#  '서부농수산물도매시장',
#  '서석동 공영주차장',
#  '서창한옥문화관',
#  '소태역 환승주차장',
#  '송암동주민센터',
#  '양3동주민센터',
#  '양동주민센터',
#  '운남동 공영주차장',
#  '유덕동주민센터',
#  '이마트 광산점',
#  '임곡동 주민센터',
#  '장덕도서관',
#  '전기안전공사 광주전남지역',
#  '정부광주합동청사',
#  '주월동 공영주차장',
#  '중소기업진흥공단 호남연수원',
#  '평동주민센터',
#  '한국광기술원',
#  '한국환경공단 호남지역본부',
#  '효죽공영주차장',
#  'KT가정빌딩',
#  '갈마도서관',
#  '관저2동주민센터',
#  '관저문예회관 공영주차장',
#  '관저저류지주차장',
#  '구즉동 주민센터',
#  '기성동 공영주차장',
#  '남선공원',
#  '노은농수산물시장',
#  '대덕대학교',
#  '대덕문화체육관',
#  '대덕보건소',
#  '대사동 공영주차장',
#  '대전 농업기술센터',
#  '대전광역시동부교육지원청',
#  '대전월드컵경기장',
#  '대전정부청사 내 주차장',
#  '대전중구보건지소',
#  '대전추모공원',
#  '대전테크노파크 주차장',
#  '대청호자연수변공원 주차장',
#  '도마2동 옆 공영주차장',
#  '동구 아름다운복지관',
#  '동구국민체육센터',
#  '롯데마트 노은점',
#  '롯데마트 대덕테크노밸리점',
#  '롯데마트 서대전점',
#  '만년동 공영주차장',
#  '목원대학교',
#  '반석역 환승주차장',
#  '변동 제1공영주차장',
#  '보문종합사회복지관',
#  '복수동 제1공영주차장',
#  '복수동 제3공영주차장',
#  '복수동 제5공영주차장',
#  '사정동 제2 공영주차장',
#  '서구국민체육센터',
#  '서구노인복지관',
#  '석교동주민센터',
#  '셀프세차장(워시하우스)',
#  '수도시설관리사업소',
#  '신대노인복지관',
#  '신탄진휴게소(서울방향)',
#  '신탄진휴게소(서울방향)',
#  '안영동 제2노외 공영주차장',
#  '안영동 제3노외 주차장',
#  '오월드 내 주차장',
#  '오정농수산물시장',
#  '온천2동 주민센터',
#  '용두동 공영주차장',
#  '용문동 제2공영주차장',
#  '우암사적공원',
#  '월평1동 공영주차장',
#  '월평동공영주차장',
#  '유등노인복지관',
#  '유승기업(현대블루핸즈)',
#  '장대동 공영주차장',
#  '장동 주차장 1',
#  '장동 주차장 2',
#  '장동 주차장 4',
#  '정림동 제2공영주차장',
#  '타이어프로신탄진',
#  '탄방동 제1공영주차장',
#  '특허청 국제지식재산연수원',
#  '한국과학기술원 교육지원동(W8) 주차장',
#  '한국도로공사대전지사',
#  '한국원자력연구원 제1주차장',
#  '한국조폐공사',
#  '한국조폐공사ID본부',
#  '한국지질자원연구원',
#  '한국환경공단 충청권지역본부',
#  '현대자동차(반석점)',
#  '홈플러스 대전탄방점',
#  '홈플러스 동대전점',
#  '홍도동주민센터',
#  '효문화진흥원',
#  '간절곶공원',
#  '강동동 주민센터',
#  '구영공원 공영주차장',
#  '남목1동 주민센터',
#  '농소1동 주민센터',
#  '농소2동 주민센터',
#  '덕신공공주차장',
#  '동구 대학1길 공영주차장',
#  '두서면사무소',
#  '롯데마트 울산점',
#  '매곡1산업단지 공영주차장',
#  '매곡3산업단지 공영주차장',
#  '모듈화산업단지 제2공영주차장',
#  '모듈화산업단지제1 공영주차장',
#  '문화의전당',
#  '방어동행정복지센터',
#  '범서읍 제2민원실 공영주차장',
#  '보람병원 앞 공영주차장',
#  '삼산1 공영주차장',
#  '상북 배내2 공영주차장',
#  '상북농공단지 공영주차장',
#  '성남공영주차장',
#  '송정동 주민센터',
#  '수협 직판장 주차장',
#  '야음공영주차장',
#  '언양강변 공영주차장',
#  '언양공영주차장',
#  '언양휴게소(서울방향)',
#  '옥류천 공영주차장',
#  '온산문화체육센터',
#  '왕생이공원공영주차장',
#  '우진휴게소',
#  '울산 동구 전하체육센터',
#  '울산 문화예술회관',
#  '울산 울주군 서생면사무소',
#  '울산 중구 동천체육관',
#  '울산공항',
#  '울산광역시 중구청',
#  '울산광역시교육청',
#  '울산남구견인차량보관소',
#  '울산농수산물종합유통센터',
#  '울산대공원 남문주차장(파크골프장)',
#  '울산대학교',
#  '울산도서관',
#  '울산동구청',
#  '울산박물관',
#  '울산병원 앞 공영주차장',
#  '울산시 북구청',
#  '울산시청',
#  '울산중부경찰서',
#  '울산체육공원 문수구장',
#  '울주군청',
#  '웅촌면사무소',
#  '일산동 공영주차장',
#  '장생포 고래문화마을 소형주차장',
#  '전하 공영주차장',
#  '창평공영주차장',
#  '태화강국가공원',
#  '평창현대앞 공영주차장',
#  '하이테크타운',
#  '한국동서발전 본사',
#  '홈플러스 울산남구점',
#  '홈플러스 울산북구점',
#  '화동 공영주차장',
#  '화정지하 공영주차장',
#  '효문동 주민센터',
#  '효암알뜰주유소',
#  'LH 세종본부',
#  '고복저수지 연기대첩비공원 주차장',
#  '도담동 싱싱장터주차장',
#  '반곡동 수변공원',
#  '보람동 수변공원',
#  '새롬동 복합커뮤니티 센터',
#  '세종정부청사 13-2동',
#  '세종정부청사 6동',
#  '세종청사1동 국무조정실',
#  '세종청사4동 기획재정부',
#  '세종청사7동 법제처',
#  '세종호수공원제2주차장',
#  '원수산 아래 BMX경기장',
#  '은하수공원',
#  '정부세종청사',
#  '정부세종컨벤션센터',
#  '첫마을 BRT 환승주차장 A',
#  '첫마을 BRT 환승주차장 B',
#  '한솔동 복합커뮤니티센터 정음관',
#  'KH양주휴게소',
#  'SK 셀프 신현주유소(영광셀프주유소)',
#  'VIC마켓 킨텍스점',
#  '㈜안성내츄럴리조트',
#  '가능동 입체공영주차장(건물식주차장)',
#  '가평군청',
#  '가평환경성질환 예방관리센터',
#  '가평휴게소(서울방향)',
#  '가평휴게소(서울방향)',
#  '가평휴게소(춘천방향)',
#  '가평휴게소(춘천방향)',
#  '갈현동 주민센터 주차장',
#  '감악산관리사무소',
#  '개군면복지회관',
#  '개군면사무소',
#  '갯골생태공원',
#  '경기광주휴게소(서울방향)',
#  '경기광주휴게소(원주방향)',
#  '경기테크노파크',
#  '경안동 공영주차장',
#  '경안시장 공영주차장',
#  '경진셀프주유소',
#  '고양시청',
#  '고양종합운동장 부설주차장',
#  '고잔동무료주차장',
#  '곡반정동 제2공영주차장',
#  '공단삼거리 공영주차장(B)',
#  '공릉관광지',
#  '공영주차장116호',
#  '과천시청',
#  '관문체육공원',
#  '관악역 3환승 공영주차장 ',
#  '광남생활체육공원',
#  '광적생활체육공원 (양주문화예술회관)',
#  '광주시민체육관',
#  '구리남양주 교육지원청',
#  '구리시 행정복지센터',
#  '구리시청',
#  '구리한강시민공원(주차장)',
#  '구리휴게소(외측방향)',
#  '국민건강보험공단 김포지사',
#  '근로복지공단 안산병원',
#  '금학공영주차장',
#  '기흥휴게소(부산방향)',
#  '김포시 장기도서관',
#  '김포시민회관',
#  '꿈나무도서관',
#  '남부수자원생태공원',
#  '남양읍사무소',
#  '남양주 시청',
#  '내촌교육문화센터',
#  '노작공원',
#  '다산행정복지센터',
#  '단월면 복지회관',
#  '대곶면행정복지센터',
#  '대부도 공영 주차장',
#  '덕양구청 주차장',
#  '덕평휴게소(강릉방향)',
#  '덕평휴게소(강릉방향)',
#  '덕평휴게소(인천방향)',
#  '동안구청',
#  '동양컴퓨터학원 앞(공중전화부스)',
#  '동탄2수질복원센터',
#  '로보파크',
#  '롯데마트 고양점',
#  '롯데마트 광교점',
#  '롯데마트 권선점',
#  '롯데마트 김포한강점',
#  '롯데마트 덕소점',
#  '롯데마트 동두천점',
#  '롯데마트 마석점',
#  '롯데마트 마장휴게소점(통영방향)',
#  '롯데마트 상록점',
#  '롯데마트 서현점',
#  '롯데마트 수원점',
#  '롯데마트 수지점',
#  '롯데마트 시흥배곧점',
#  '롯데마트 신갈점',
#  '롯데마트 신영통점',
#  '롯데마트 안산점',
#  '롯데마트 안성점',
#  '롯데마트 양주점',
#  '롯데마트 영통점',
#  '롯데마트 영통점',
#  '롯데마트 오산점',
#  '롯데마트 의왕점',
#  '롯데마트 의정부점',
#  '롯데마트 장암점',
#  '롯데마트 주엽점',
#  '롯데마트 천천점',
#  '롯데마트 판교점',
#  '롯데마트 평택점',
#  '롯데마트 피트인산본점',
#  '롯데마트 화정점',
#  '롯데아울렛 이천점1',
#  '롯데프리미엄아울렛파주점',
#  '마장복합휴게소',
#  '마장호수관리사무소',
#  '만안구청',
#  '매송휴게소(목포방향)',
#  '매송휴게소(시흥방향)',
#  '문화재청 왕릉유적본부  서부지구관리소(김포장릉)',
#  '물왕영업소',
#  '미사리 경정공원 제2주차장',
#  '미사리 경정공원 제8주차장',
#  '반월역환승주차장',
#  '백석천 제1지하주차장(건물식/지하)',
#  '백석천지하2 공영주차장',
#  '별내동주민센터',
#  '본오1동행정복지센터',
#  '본오동56호무료주차장',
#  '부발읍행정복지센터',
#  '부천수자원생태공원',
#  '부천시민회관 부설주차장',
#  '부천종합운동장',
#  '북한산국립공원 원도봉 제3주차장',
#  '비둘기낭 캠핑장',
#  '비봉영업소',
#  '비전 공영주차장',
#  '사동124호무료주차장',
#  '사동47호무료주차장',
#  '산정지 주차장',
#  '상동 호수공원주차장',
#  '상록구청',
#  '상번천리공영주차장',
#  '서수원칠보체육관',
#  '서여주휴게소(마산방향)',
#  '서여주휴게소(양평방향)',
#  '서하남휴게소(판교방향)',
#  '선단동주민센터',
#  '선돌공원',
#  '선부동26호무료주차장',
#  '성남 맛고을 주차장',
#  '성남시청',
#  '성남시청',
#  '성남아트센터 옥외주차장',
#  '성남휴게소(외측방향)',
#  '성호공원 주차장',
#  '세류역 환승주차장',
#  '세화제2주유소',
#  '센트럴파크',
#  '소사어울림마당 주차장',
#  '소요산축산물브랜드육타운 공영주차장',
#  '송산포도휴게소(시흥방향)',
#  '송산포도휴게소(평택방향)',
#  '송전휴게소',
#  '송죽공영주차장',
#  '송추 제2주차장',
#  '송탄역 공영주차장',
#  '수동면주민자치센터',
#  '수락산 공영주차장',
#  '수원도시공사',
#  '수원종합운동장 8주차장',
#  '수원컨벤션센터',
#  '수원화성박물관',
#  '스타필드 고양',
#  '스타필드 부천점1',
#  '스타필드 위례',
#  '시민체육광장',
#  '시흥본선상공형휴게시설휴게소(일산방향)',
#  '시흥본선상공형휴게시설휴게소(판교방향)',
#  '안산문화예술의전당',
#  '안산역환승주차장',
#  '안산호수공원 3 주차장',
#  '안성맞춤휴게소(음성방향)',
#  '안성맞춤휴게소(제천방향)',
#  '안성맞춤휴게소(평택방향)',
#  '안성맞춤휴게소(평택방향)',
#  '안성시청',
#  '안성휴게소(부산방향)',
#  '안성휴게소(서울방향)',
#  '안성휴게소(서울방향)',
#  '안양시청',
#  '양동면사무소',
#  '양주시청',
#  '양평공영주차장',
#  '양평군민회관',
#  '양평휴게소(광주방향)',
#  '양평휴게소(원주방향)',
#  '어린이비젼센터 주차장',
#  '에코랜드',
#  '에코스포츠센터 1주차장',
#  '여주보건소',
#  '여주휴게소(강릉방향)',
#  '여주휴게소(강릉방향)',
#  '여주휴게소(서창방향)',
#  '여주휴게소(인천방향)',
#  '역동공영주차장',
#  '연천군청',
#  '영북체육문화센터',
#  '영중면사무소',
#  '예술공원 노외주차장',
#  '예스파크 2주차장',
#  '오산휴게소(과천방향)',
#  '오산휴게소(동탄방향)',
#  '오정어울마당',
#  '옥정중앙공원',
#  '와동30호무료주차장',
#  '와동54호무료주차장',
#  '와동주민센터무료주차장(31호)',
#  '와부읍 제3공영주차장',
#  '용문생활체육공원',
#  '용인시민체육공원',
#  '용인시청',
#  '용인휴게소(강릉방향)',
#  '용인휴게소(서창방향)',
#  '원곡동45호무료주차장 ',
#  '월롱면사무소',
#  '월피동29호무료주차장',
#  '유비파크 2주차장',
#  '유앤아이센터',
#  '유카스주유소',
#  '율동자연공원 B주차장',
#  '의왕휴게소(서울방향)',
#  '의왕휴게소(의왕방향)',
#  '이마트 광명소하점',
#  '이마트 김포한강점',
#  '이마트 남양주점',
#  '이마트 도농점',
#  '이마트 보라점',
#  '이마트 서수원점',
#  '이마트 성남점',
#  '이마트 오산점',
#  '이마트 이천점',
#  '이마트 죽전점',
#  '이마트 중동점',
#  '이마트 파주운정점',
#  '이마트 파주점',
#  '이마트 하남점',
#  '이마트 하남점',
#  '이천휴게소(통영방향)',
#  '이천휴게소(하남방향)',
#  '이충레포츠공원',
#  '일산동구청',
#  '일산서구청 내  주차장',
#  '임진각관광지 주차장',
#  '자동차안전연구원',
#  '장안구청',
#  '장암역 환승공영주차장',
#  '장암주유소',
#  '죽산면사무소',
#  '죽전휴게소(서울방향)',
#  '중소기업연수원',
#  '지평면사무소',
#  '진접체육문화센터',
#  '차량등록사업소 뒷편 주차장',
#  '청소년수련관',
#  '청운면사무소',
#  '청평면사무소',
#  '축석령휴게소',
#  '통진공영주차장',
#  '통진두레문화센터',
#  '파주시청광장 주차장',
#  '파주택시쉼터',
#  '팔곡이동129호무료주차장',
#  '평택항여객터미널 주차장',
#  '포곡읍사무소',
#  '포천반월아트홀',
#  '하나로마트 성남점',
#  '하남만남휴게소(통영방향)',
#  '하남미사 근린공원15호 주차장',
#  '하남미사 근린공원16호 주차장',
#  '하남미사 수변공원3호 주차장',
#  '하남벤처센터',
#  '하남유니온파크',
#  '학온동주민센터',
#  '한강유역환경청',
#  '한국주택토지공사 동탄사업본부',
#  '한국폴리텍대학 안성캠퍼스',
#  '헤이리아트밸리',
#  '홈플러스 경기일산점',
#  '홈플러스 동수원점',
#  '홈플러스 병점점',
#  '홈플러스 송탄점',
#  '홈플러스 시화점',
#  '홈플러스 안산점',
#  '홈플러스 안양점',
#  '홈플러스 오산점',
#  '홈플러스 의정부점',
#  '홈플러스 파주문산점',
#  '홈플러스 풍무점',
#  '화도읍 제2공영주차장',
#  '화랑유원지 2주차장',
#  '화성시청',
#  '화성휴게소(목포방향)',
#  '화성휴게소(목포방향)',
#  '화성휴게소(시흥방향)',
#  '화성휴게소(시흥방향)',
#  '회암사지박물관',
#  '(구)거진수산센터 주차장',
#  '38선 휴게소',
#  '5일장 앞 공영주차장',
#  'GS연화주유소',
#  'SK 척산주유소',
#  '가곡면 행복문화센터',
#  '간동면사무소',
#  '간현국민관광지 주차장',
#  '갈말읍사무소 주차장',
#  '강릉시청',
#  '강릉종합운동장',
#  '강릉휴게소(강릉방향)',
#  '강릉휴게소(인천방향)',
#  '강림면사무소',
#  '강북공설운동장',
#  '강원대학교 서암관',
#  '강원도 인재개발원',
#  '강원도립화목원',
#  '강원도산업경제진흥원',
#  '강원도청',
#  '거두리잔디구장',
#  '거진시장 주차장',
#  '거진읍공설운동장',
#  '고석정 주차장',
#  '고석정주차장',
#  '고성군청 후면주차장',
#  '고원관광휴게소',
#  '고한읍사무소',
#  '공근면사무소',
#  '구곡폭포주차장',
#  '구정휴게소(동해방향)',
#  '구정휴게소(속초방향)',
#  '국립공원관리공단 본부',
#  '국립산악박물관',
#  '국민건강보험공단 삼척지사',
#  '국민연금공단 강릉사옥',
#  '국민연금공단 춘천사옥',
#  '국회고성연수원',
#  '근남면사무소 주차장',
#  '기린 제1공영주차장',
#  '김화읍사무소 주차장',
#  '낙산해수욕장주차장',
#  '남면 화전농공단지 구내식당 앞 주차장',
#  '남면사무소',
#  '남면사무소 주차장',
#  '내린천휴게소 서울방향',
#  '내린천휴게소 양양방향',
#  '내촌체육공원',
#  '노곡면 복지회관',
#  '노학동 주민센터',
#  '농산물도매시장',
#  '농업기술센터',
#  '대이동굴관광센터앞 주차장',
#  '대화면사무소',
#  '더케이설악산가족호텔',
#  '덕포보건지소',
#  '도계종합회관 주차장',
#  '동면농협 하나로마트',
#  '동면사무소',
#  '동면사무소 주차장',
#  '동송공영주차장',
#  '동해문화예술회관',
#  '동해웰빙레포츠타운 주차장',
#  '동해휴게소(동해방향)',
#  '둔내면사무소',
#  '등선폭포주차장',
#  '따뚜주차장',
#  '롯데마트 석사점',
#  '롯데마트 원주점',
#  '롯데마트 춘천점',
#  '망상해수욕장 2주차장',
#  '무릉계곡',
#  '무릉공원',
#  '묵호항수변공원 주차장 ',
#  '문막생활체육공원',
#  '문막휴게소(강릉방향)',
#  '문막휴게소(강릉방향)',
#  '문막휴게소(서창방향)',
#  '물치해안공원 주차장',
#  '미탄면사무소',
#  '민둥산 운동장',
#  '반곡관설동 행정복지센터',
#  '방림면사무소',
#  '사창리 공영주차장',
#  '산림조합 앞 공영주차장',
#  '산천어시네마',
#  '삼척관광호텔',
#  '삼척동해태백산림조합',
#  '삼척번개시장',
#  '삼척시청',
#  '삼척시평생학습관',
#  '삼척종합운동장',
#  '삼척해양레일바이크',
#  '삼천동 공영주차장',
#  '상남 제1공영주차장',
#  '상리주차장',
#  '샘밭장터 농특산물전시판매장',
#  '서곡8리 공영주차장',
#  '서면사무소',
#  '서면사무소 주차장',
#  '서석면사무소',
#  '석탄회관 앞 공영주차장',
#  '선등거리 주차타워',
#  ...]

# %%
print(len(nouse), len(using), len(ben), len(charge))
# Out:
# 2492 2492 2492 2492

# %%
len(amount)
# Out:
# 2492

# %%
df = pd.DataFrame({'이름':name, '사용가능시간':time,'구분':typ, '충전기타입':charge, '사용가능':nouse,'사용중':using,'사용불가':ben,'도로명주소':add,'연락처':phone,'충전요금':fee, '급속충전량':amount,'참고사항':etc})
df.head()
# Out:
#                 이름     사용가능시간  구분            충전기타입  사용가능  사용중  사용불가  \
# 0     DMC 산학협력연구센터  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
# 1  Park M (주차복합빌딩)  24시간 이용가능  급속             DC콤보     2    0     0
# 2            SETEC  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     0    1     0
# 3       sh서울주택도시공사  24시간 이용가능  급속             DC콤보     2    0     0
# 4    가로공원로 지하공영주차장  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
#
#                            도로명주소        연락처 충전요금        급속충전량  \
# 0             서울특별시 마포구 매봉산로 37   1661-9408   유료  급속(100kW멀티)
# 1             서울특별시 마포구 매봉산로 80   1661-9408   무료  급속(200kW동시)
# 2           서울특별시 강남구 남부순환로3104   1661-9408   유료  급속(100kW멀티)
# 3             서울특별시 강남구 개포로 621   1661-9408   유료  급속(200kW동시)
# 4  서울특별시 강서구 가로공원로 189  지하주차장 05  1661-9408   유료     급속(50kW)
#
#                                     참고사항
# 0                              10분/500원
# 1  최초30분 1500원, 10분당 500원 주민센터이용 50% 할인
# 2    충전차량에한하여 1시간무료 10분당500월 일주차15,000원
# 3                                    없음
# 4                               주차요금 별도

# %%
df
# Out:
#                    이름     사용가능시간  구분            충전기타입  사용가능  사용중  사용불가  \
# 0        DMC 산학협력연구센터  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
# 1     Park M (주차복합빌딩)  24시간 이용가능  급속             DC콤보     2    0     0
# 2               SETEC  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     0    1     0
# 3          sh서울주택도시공사  24시간 이용가능  급속             DC콤보     2    0     0
# 4       가로공원로 지하공영주차장  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
# ...               ...        ...  ..              ...   ...  ...   ...
# 2487          홍로공영주차장  24시간 이용가능  급속             DC콤보     0    1     0
# 2488          화북동주민센터  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
# 2489      환경성질환예방관리센터  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
# 2490   회수사거리 인근 공영주차장  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
# 2491          효돈동주민센터  24시간 이용가능  급속  DC차데모+AC3상+DC콤보     1    0     0
#
#                                                   도로명주소        연락처 충전요금  \
# 0                                    서울특별시 마포구 매봉산로 37   1661-9408   유료
# 1                                    서울특별시 마포구 매봉산로 80   1661-9408   무료
# 2                                  서울특별시 강남구 남부순환로3104   1661-9408   유료
# 3                                    서울특별시 강남구 개포로 621   1661-9408   유료
# 4                         서울특별시 강서구 가로공원로 189  지하주차장 05  1661-9408   유료
# ...                                                 ...        ...  ...
# 2487                           제주특별자치도 서귀포시 동홍동 1480-6   1661-9408   무료
# 2488                           제주특별자치도 제주시 화북1동 1976-6   1661-9408   유료
# 2489  제주특별자치도 제주시 구좌읍 다랑쉬북로 68-92 환경성질환예방관리센터(평대리 2981)  1661-9408   유료
# 2490                            제주특별자치도 서귀포시 회수동 788-2   1661-9408   유료
# 2491                          제주특별자치도 서귀포시 효돈로 152번길 7   1661-9408   유료
#
#             급속충전량                                   참고사항
# 0     급속(100kW멀티)                              10분/500원
# 1     급속(200kW동시)  최초30분 1500원, 10분당 500원 주민센터이용 50% 할인
# 2     급속(100kW멀티)    충전차량에한하여 1시간무료 10분당500월 일주차15,000원
# 3     급속(200kW동시)                                    없음
# 4        급속(50kW)                               주차요금 별도
# ...           ...                                    ...
# 2487  급속(100kW멀티)                          주간 유료, 야간 무료
# 2488     급속(50kW)                               주차요금 별도
# 2489     급속(50kW)                                    없음
# 2490     급속(50kW)                               주차요금 별도
# 2491  급속(100kW멀티)                                    없음
#
# [2492 rows x 12 columns]

# %%
from sqlalchemy import create_engine
import pymysql

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

# %%
engine = create_engine("mysql+mysqldb://root:"+"1234"+"@192.168.0.146/test", encoding='utf-8')
conn = engine.connect()

# %%
df.to_sql(name='ev_new2', con=engine, if_exists='append', index=False)

# %%
conn.close()

# %%
host_name = "192.168.0.146"
username = "root"
password = "1234"
database_name = "test"

# %%
db = pymysql.connect(
    host=host_name,  # DATABASE_HOST
    port=3306,
    user=username,  # DATABASE_USERNAME
    passwd=password,  # DATABASE_PASSWORD
    db=database_name,  # DATABASE_NAME
    charset='utf8'
)

# %%
SQL = "SELECT * FROM ev_new LIMIT 5"
df = pd.read_sql(SQL, db)
df
# Out:
#                 이름     사용가능시간  구분  사용가능  사용중  사용불가  \
# 0     DMC 산학협력연구센터  24시간 이용가능  급속     1    0     0
# 1  Park M (주차복합빌딩)  24시간 이용가능  급속     1    1     0
# 2            SETEC  24시간 이용가능  급속     0    1     0
# 3       sh서울주택도시공사  24시간 이용가능  급속     2    0     0
# 4    가로공원로 지하공영주차장  24시간 이용가능  급속     1    0     0
#
#                            도로명주소        연락처 충전요금        급속충전량  \
# 0             서울특별시 마포구 매봉산로 37   1661-9408   유료  급속(100kW멀티)
# 1             서울특별시 마포구 매봉산로 80   1661-9408   무료  급속(200kW동시)
# 2           서울특별시 강남구 남부순환로3104   1661-9408   유료  급속(100kW멀티)
# 3             서울특별시 강남구 개포로 621   1661-9408   유료  급속(200kW동시)
# 4  서울특별시 강서구 가로공원로 189  지하주차장 05  1661-9408   유료     급속(50kW)
#
#                                     참고사항
# 0                              10분/500원
# 1  최초30분 1500원, 10분당 500원 주민센터이용 50% 할인
# 2    충전차량에한하여 1시간무료 10분당500월 일주차15,000원
# 3                                    없음
# 4                               주차요금 별도
